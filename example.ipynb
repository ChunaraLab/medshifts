# %%
import numpy as np
from tensorflow import set_random_seed
seed = 1
np.random.seed(seed)
set_random_seed(seed)

from shift_detector import *
from shift_locator import *
from shift_applicator import *
from data_utils import *
import os
import sys
from exp_utils import *

# -------------------------------------------------
# PLOTTING HELPERS
# -------------------------------------------------

import matplotlib.pyplot as plt
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
rc('axes', labelsize=20)
rc('xtick', labelsize=20)
rc('ytick', labelsize=20)
rc('legend', fontsize=12)

def clamp(val, minimum=0, maximum=255):
    if val < minimum:
        return minimum
    if val > maximum:
        return maximum
    return val

def colorscale(hexstr, scalefactor):
    hexstr = hexstr.strip('#')

    if scalefactor < 0 or len(hexstr) != 6:
        return hexstr

    r, g, b = int(hexstr[:2], 16), int(hexstr[2:4], 16), int(hexstr[4:], 16)

    r = clamp(r * scalefactor)
    g = clamp(g * scalefactor)
    b = clamp(b * scalefactor)

    return "#%02x%02x%02x" % (int(r), int(g), int(b))

linestyles = ['-', '-.', '--', ':']
brightness = [1.25, 1.0, 0.75, 0.5]
format = ['-o', '-h', '-p', '-s', '-D', '-<', '->', '-X']
markers = ['o', 'h', 'p', 's', 'D', '<', '>', 'X']
colors_old = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
              '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
              '#bcbd22', '#17becf']
colors = ['#2196f3', '#f44336', '#9c27b0', '#64dd17', '#009688', '#ff9800', '#795548', '#607d8b']

def errorfill(x, y, yerr, color=None, alpha_fill=0.2, ax=None, fmt='-o', label=None):
    ax = ax if ax is not None else plt.gca()
    if color is None:
        color = next(ax._get_lines.prop_cycler)['color']
    if np.isscalar(yerr) or len(yerr) == len(y):
        ymin = y - yerr
        ymax = y + yerr
    elif len(yerr) == 2:
        ymin, ymax = yerr
    ax.semilogx(x, y, fmt, color=color, label=label)
    ax.fill_between(x, np.clip(ymax, 0, 1), np.clip(ymin, 0, 1), color=color, alpha=alpha_fill)
# Out:
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /anaconda3/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
# -------------------------------------------------
# CONFIG
# -------------------------------------------------

make_keras_picklable()
np.set_printoptions(threshold=sys.maxsize)

sys.argv = ['pipeline.py', 'mnist', 'orig', 'univ']

datset = sys.argv[1]
test_type = sys.argv[3]

path = './paper_results/'
path += test_type + '/'
path += datset + '_'
path += sys.argv[2] + '/'

if not os.path.exists(path):
    os.makedirs(path)

# Define DR methods
dr_techniques = [DimensionalityReduction.NoRed.value, DimensionalityReduction.PCA.value, DimensionalityReduction.SRP.value, DimensionalityReduction.UAE.value, DimensionalityReduction.TAE.value, DimensionalityReduction.BBSDs.value, DimensionalityReduction.BBSDh.value]
if test_type == 'multiv':
    dr_techniques = [DimensionalityReduction.NoRed.value, DimensionalityReduction.PCA.value, DimensionalityReduction.SRP.value, DimensionalityReduction.UAE.value, DimensionalityReduction.TAE.value, DimensionalityReduction.BBSDs.value]
if test_type == 'univ':
    dr_techniques_plot = dr_techniques.copy()
    dr_techniques_plot.append(DimensionalityReduction.Classif.value)
else:
    dr_techniques_plot = dr_techniques.copy()

# Define test types and general test sample sizes
test_types = [td.value for td in TestDimensionality]
if test_type == 'multiv':
    od_tests = []
    md_tests = [MultidimensionalTest.MMD.value]
    samples = [10, 20, 50, 100, 200, 500, 1000]
else:
#     od_tests = [od.value for od in OnedimensionalTest]
    od_tests = [OnedimensionalTest.KS.value]
    md_tests = []
    samples = [10, 20, 50, 100, 200, 500, 1000, 9000]
difference_samples = 10

# Number of random runs to average results over    
random_runs = 2

# Signifiance level
sign_level = 0.05

# Define shift types
if sys.argv[2] == 'small_gn_shift':
    shifts = ['rand','small_gn_shift_0.1', 'small_gn_shift_0.5', 'small_gn_shift_1.0']
elif sys.argv[2] == 'medium_gn_shift':
    shifts = ['rand','medium_gn_shift_0.1', 'medium_gn_shift_0.5', 'medium_gn_shift_1.0']
elif sys.argv[2] == 'large_gn_shift':
    shifts = ['rand', 'large_gn_shift_0.1', 'large_gn_shift_0.5', 'large_gn_shift_1.0']
elif sys.argv[2] == 'adversarial_shift':
    shifts = ['rand','adversarial_shift_0.1', 'adversarial_shift_0.5', 'adversarial_shift_1.0']
elif sys.argv[2] == 'ko_shift':
    shifts = ['rand','ko_shift_0.1', 'ko_shift_0.5', 'ko_shift_1.0']
    if test_type == 'univ':
        samples = [10, 20, 50, 100, 200, 500, 1000, 9000]
elif sys.argv[2] == 'orig':
    shifts = ['rand', 'orig']
    brightness = [1.25, 0.75]
elif sys.argv[2] == 'small_image_shift':
    shifts = ['rand', 'small_img_shift_0.1', 'small_img_shift_0.5', 'small_img_shift_1.0']
elif sys.argv[2] == 'medium_image_shift':
    shifts = ['rand','medium_img_shift_0.1', 'medium_img_shift_0.5', 'medium_img_shift_1.0']
elif sys.argv[2] == 'large_image_shift':
    shifts = ['rand','large_img_shift_0.1', 'large_img_shift_0.5', 'large_img_shift_1.0']
elif sys.argv[2] == 'medium_img_shift+ko_shift':
    shifts = ['rand', 'medium_img_shift_0.5+ko_shift_0.1', 'medium_img_shift_0.5+ko_shift_0.5', 'medium_img_shift_0.5+ko_shift_1.0']
    if test_type == 'univ':
        samples = [10, 20, 50, 100, 200, 500, 1000, 9000]
elif sys.argv[2] == 'only_zero_shift+medium_img_shift':
    shifts = ['rand', 'only_zero_shift+medium_img_shift_0.1', 'only_zero_shift+medium_img_shift_0.5', 'only_zero_shift+medium_img_shift_1.0']
    samples = [10, 20, 50, 100, 200, 500, 1000]
else:
    shifts = []

# %%
samples_shifts_rands_dr_tech = np.ones((len(samples), len(shifts), random_runs, len(dr_techniques) + 1)) * (-1)

red_dim = -1
red_models = [None] * len(DimensionalityReduction)

# %%
shift_idx, shift = 0, 'rand'
shift_path = path + shift + '/'
if not os.path.exists(shift_path):
    os.makedirs(shift_path)

rand_run_p_vals = np.ones((len(samples), len(dr_techniques) + 1, random_runs)) * (-1)

# %%
rand_run = 0

print("Random run %s" % rand_run)

rand_run_path = shift_path + str(rand_run) + '/'
if not os.path.exists(rand_run_path):
    os.makedirs(rand_run_path)

np.random.seed(rand_run)
set_random_seed(rand_run)

# Load data
(X_tr_orig, y_tr_orig), (X_val_orig, y_val_orig), (X_te_orig, y_te_orig), orig_dims, nb_classes = import_dataset(datset, shuffle=True)
X_tr_orig = normalize_datapoints(X_tr_orig, 255.)
X_te_orig = normalize_datapoints(X_te_orig, 255.)
X_val_orig = normalize_datapoints(X_val_orig, 255.)
# Out:
# Random run 0
# (28, 28, 1)

# %%
if shift == 'orig':
    print('Original')
    (X_tr_orig, y_tr_orig), (X_val_orig, y_val_orig), (X_te_orig, y_te_orig), orig_dims, nb_classes = import_dataset(datset)
    X_tr_orig = normalize_datapoints(X_tr_orig, 255.)
    X_te_orig = normalize_datapoints(X_te_orig, 255.)
    X_val_orig = normalize_datapoints(X_val_orig, 255.)
    X_te_1 = X_te_orig.copy()
    y_te_1 = y_te_orig.copy()
else:
    (X_te_1, y_te_1) = apply_shift(X_te_orig, y_te_orig, shift, orig_dims, datset)

X_te_2 , y_te_2 = random_shuffle(X_te_1, y_te_1)
# Out:
# Randomized

# %%
si, sample = 0, 10

print("Sample %s" % sample)

sample_path = rand_run_path + str(sample) + '/'
if not os.path.exists(sample_path):
    os.makedirs(sample_path)

X_te_3 = X_te_2[:sample,:]
x_te_3_samp = X_te_3[0]
y_te_3 = y_te_2[:sample]

if test_type == 'multiv':
    X_val_3 = X_val_orig[:1000,:]
    y_val_3 = y_val_orig[:1000]
else:
    X_val_3 = np.copy(X_val_orig)
    y_val_3 = np.copy(y_val_orig)

X_tr_3 = np.copy(X_tr_orig)
y_tr_3 = np.copy(y_tr_orig)
# Out:
# Sample 10

# %%
dr_ind, dr_technique = 6, 6
shift_reductor = ShiftReductor(X_tr_3, y_tr_3, X_val_3, y_val_3, DimensionalityReduction(dr_technique), orig_dims, datset, dr_amount=32)
shift_reductor_model = shift_reductor.fit_reductor()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/2
# 50000/50000 [==============================] - 513s 10ms/step - loss: 0.2469 - accuracy: 0.9243 - val_loss: 0.2358 - val_accuracy: 0.9355
# Epoch 2/2
# 50000/50000 [==============================] - 479s 10ms/step - loss: 0.0489 - accuracy: 0.9849 - val_loss: 0.0726 - val_accuracy: 0.9776

# %%
shift_reductor_model.save('./saved_models/test.h5')

# %%
from keras.utils.io_utils import H5Dict

h5dict = H5Dict('./saved_models/test.h5', mode='r')
# model_from_config(model_config, custom_objects=custom_objects)

# %%
import json

model_config = h5dict['model_config']
model_config = json.loads(model_config.decode('utf-8'))

# %%
from keras.engine.saving import model_from_config
from keras.layers import deserialize
from keras import models
from keras.utils.generic_utils import deserialize_keras_object, has_arg, _GLOBAL_CUSTOM_OBJECTS

globs = globals()  # All layers.
globs['Model'] = models.Model
globs['Sequential'] = models.Sequential

class_name = model_config['class_name']

# d = deserialize_keras_object(model_config,
#                             module_objects=globs,
#                             custom_objects=keras_resnet.custom_objects,
#                             printable_module_name='layer')
# d = deserialize(model_config, custom_objects=keras_resnet.custom_objects)
# model = model_from_config(model_config, custom_objects=keras_resnet.custom_objects)

# %%
model_config
# Out:
# {'class_name': 'ResNet2D18',
#  'config': {'name': 'resnet2d18_3',
#   'layers': [{'name': 'input_8',
#     'class_name': 'InputLayer',
#     'config': {'batch_input_shape': [None, 28, 28, 1],
#      'dtype': 'float32',
#      'sparse': False,
#      'name': 'input_8'},
#     'inbound_nodes': []},
#    {'name': 'conv1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'conv1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': [7, 7],
#      'strides': [2, 2],
#      'padding': 'same',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['input_8', 0, 0, {}]]]},
#    {'name': 'bn_conv1',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn_conv1',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['conv1', 0, 0, {}]]]},
#    {'name': 'conv1_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'conv1_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['bn_conv1', 0, 0, {}]]]},
#    {'name': 'pool1',
#     'class_name': 'MaxPooling2D',
#     'config': {'name': 'pool1',
#      'trainable': True,
#      'dtype': 'float32',
#      'pool_size': [3, 3],
#      'padding': 'same',
#      'strides': [2, 2],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['conv1_relu', 0, 0, {}]]]},
#    {'name': 'padding2a_branch2a',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding2a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['pool1', 0, 0, {}]]]},
#    {'name': 'res2a_branch2a',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res2a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding2a_branch2a', 0, 0, {}]]]},
#    {'name': 'bn2a_branch2a',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn2a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res2a_branch2a', 0, 0, {}]]]},
#    {'name': 'res2a_branch2a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res2a_branch2a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['bn2a_branch2a', 0, 0, {}]]]},
#    {'name': 'padding2a_branch2b',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding2a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res2a_branch2a_relu', 0, 0, {}]]]},
#    {'name': 'res2a_branch2b',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res2a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding2a_branch2b', 0, 0, {}]]]},
#    {'name': 'res2a_branch1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res2a_branch1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': [1, 1],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['pool1', 0, 0, {}]]]},
#    {'name': 'bn2a_branch2b',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn2a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res2a_branch2b', 0, 0, {}]]]},
#    {'name': 'bn2a_branch1',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn2a_branch1',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res2a_branch1', 0, 0, {}]]]},
#    {'name': 'res2a',
#     'class_name': 'Add',
#     'config': {'name': 'res2a', 'trainable': True, 'dtype': 'float32'},
#     'inbound_nodes': [[['bn2a_branch2b', 0, 0, {}],
#       ['bn2a_branch1', 0, 0, {}]]]},
#    {'name': 'res2a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res2a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['res2a', 0, 0, {}]]]},
#    {'name': 'padding2b1_branch2a',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding2b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res2a_relu', 0, 0, {}]]]},
#    {'name': 'res2b1_branch2a',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res2b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding2b1_branch2a', 0, 0, {}]]]},
#    {'name': 'bn2b1_branch2a',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn2b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res2b1_branch2a', 0, 0, {}]]]},
#    {'name': 'res2b1_branch2a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res2b1_branch2a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['bn2b1_branch2a', 0, 0, {}]]]},
#    {'name': 'padding2b1_branch2b',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding2b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res2b1_branch2a_relu', 0, 0, {}]]]},
#    {'name': 'res2b1_branch2b',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res2b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 64,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding2b1_branch2b', 0, 0, {}]]]},
#    {'name': 'bn2b1_branch2b',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn2b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res2b1_branch2b', 0, 0, {}]]]},
#    {'name': 'res2b1',
#     'class_name': 'Add',
#     'config': {'name': 'res2b1', 'trainable': True, 'dtype': 'float32'},
#     'inbound_nodes': [[['bn2b1_branch2b', 0, 0, {}],
#       ['res2a_relu', 0, 0, {}]]]},
#    {'name': 'res2b1_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res2b1_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['res2b1', 0, 0, {}]]]},
#    {'name': 'padding3a_branch2a',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding3a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res2b1_relu', 0, 0, {}]]]},
#    {'name': 'res3a_branch2a',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res3a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': [3, 3],
#      'strides': [2, 2],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding3a_branch2a', 0, 0, {}]]]},
#    {'name': 'bn3a_branch2a',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn3a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res3a_branch2a', 0, 0, {}]]]},
#    {'name': 'res3a_branch2a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res3a_branch2a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['bn3a_branch2a', 0, 0, {}]]]},
#    {'name': 'padding3a_branch2b',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding3a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res3a_branch2a_relu', 0, 0, {}]]]},
#    {'name': 'res3a_branch2b',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res3a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding3a_branch2b', 0, 0, {}]]]},
#    {'name': 'res3a_branch1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res3a_branch1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': [1, 1],
#      'strides': [2, 2],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['res2b1_relu', 0, 0, {}]]]},
#    {'name': 'bn3a_branch2b',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn3a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res3a_branch2b', 0, 0, {}]]]},
#    {'name': 'bn3a_branch1',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn3a_branch1',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res3a_branch1', 0, 0, {}]]]},
#    {'name': 'res3a',
#     'class_name': 'Add',
#     'config': {'name': 'res3a', 'trainable': True, 'dtype': 'float32'},
#     'inbound_nodes': [[['bn3a_branch2b', 0, 0, {}],
#       ['bn3a_branch1', 0, 0, {}]]]},
#    {'name': 'res3a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res3a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['res3a', 0, 0, {}]]]},
#    {'name': 'padding3b1_branch2a',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding3b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res3a_relu', 0, 0, {}]]]},
#    {'name': 'res3b1_branch2a',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res3b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding3b1_branch2a', 0, 0, {}]]]},
#    {'name': 'bn3b1_branch2a',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn3b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res3b1_branch2a', 0, 0, {}]]]},
#    {'name': 'res3b1_branch2a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res3b1_branch2a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['bn3b1_branch2a', 0, 0, {}]]]},
#    {'name': 'padding3b1_branch2b',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding3b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res3b1_branch2a_relu', 0, 0, {}]]]},
#    {'name': 'res3b1_branch2b',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res3b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 128,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding3b1_branch2b', 0, 0, {}]]]},
#    {'name': 'bn3b1_branch2b',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn3b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res3b1_branch2b', 0, 0, {}]]]},
#    {'name': 'res3b1',
#     'class_name': 'Add',
#     'config': {'name': 'res3b1', 'trainable': True, 'dtype': 'float32'},
#     'inbound_nodes': [[['bn3b1_branch2b', 0, 0, {}],
#       ['res3a_relu', 0, 0, {}]]]},
#    {'name': 'res3b1_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res3b1_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['res3b1', 0, 0, {}]]]},
#    {'name': 'padding4a_branch2a',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding4a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res3b1_relu', 0, 0, {}]]]},
#    {'name': 'res4a_branch2a',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res4a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 256,
#      'kernel_size': [3, 3],
#      'strides': [2, 2],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding4a_branch2a', 0, 0, {}]]]},
#    {'name': 'bn4a_branch2a',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn4a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res4a_branch2a', 0, 0, {}]]]},
#    {'name': 'res4a_branch2a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res4a_branch2a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['bn4a_branch2a', 0, 0, {}]]]},
#    {'name': 'padding4a_branch2b',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding4a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res4a_branch2a_relu', 0, 0, {}]]]},
#    {'name': 'res4a_branch2b',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res4a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 256,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding4a_branch2b', 0, 0, {}]]]},
#    {'name': 'res4a_branch1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res4a_branch1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 256,
#      'kernel_size': [1, 1],
#      'strides': [2, 2],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['res3b1_relu', 0, 0, {}]]]},
#    {'name': 'bn4a_branch2b',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn4a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res4a_branch2b', 0, 0, {}]]]},
#    {'name': 'bn4a_branch1',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn4a_branch1',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res4a_branch1', 0, 0, {}]]]},
#    {'name': 'res4a',
#     'class_name': 'Add',
#     'config': {'name': 'res4a', 'trainable': True, 'dtype': 'float32'},
#     'inbound_nodes': [[['bn4a_branch2b', 0, 0, {}],
#       ['bn4a_branch1', 0, 0, {}]]]},
#    {'name': 'res4a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res4a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['res4a', 0, 0, {}]]]},
#    {'name': 'padding4b1_branch2a',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding4b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res4a_relu', 0, 0, {}]]]},
#    {'name': 'res4b1_branch2a',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res4b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 256,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding4b1_branch2a', 0, 0, {}]]]},
#    {'name': 'bn4b1_branch2a',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn4b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res4b1_branch2a', 0, 0, {}]]]},
#    {'name': 'res4b1_branch2a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res4b1_branch2a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['bn4b1_branch2a', 0, 0, {}]]]},
#    {'name': 'padding4b1_branch2b',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding4b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res4b1_branch2a_relu', 0, 0, {}]]]},
#    {'name': 'res4b1_branch2b',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res4b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 256,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding4b1_branch2b', 0, 0, {}]]]},
#    {'name': 'bn4b1_branch2b',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn4b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res4b1_branch2b', 0, 0, {}]]]},
#    {'name': 'res4b1',
#     'class_name': 'Add',
#     'config': {'name': 'res4b1', 'trainable': True, 'dtype': 'float32'},
#     'inbound_nodes': [[['bn4b1_branch2b', 0, 0, {}],
#       ['res4a_relu', 0, 0, {}]]]},
#    {'name': 'res4b1_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res4b1_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['res4b1', 0, 0, {}]]]},
#    {'name': 'padding5a_branch2a',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding5a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res4b1_relu', 0, 0, {}]]]},
#    {'name': 'res5a_branch2a',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res5a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 512,
#      'kernel_size': [3, 3],
#      'strides': [2, 2],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding5a_branch2a', 0, 0, {}]]]},
#    {'name': 'bn5a_branch2a',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn5a_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res5a_branch2a', 0, 0, {}]]]},
#    {'name': 'res5a_branch2a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res5a_branch2a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['bn5a_branch2a', 0, 0, {}]]]},
#    {'name': 'padding5a_branch2b',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding5a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res5a_branch2a_relu', 0, 0, {}]]]},
#    {'name': 'res5a_branch2b',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res5a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 512,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding5a_branch2b', 0, 0, {}]]]},
#    {'name': 'res5a_branch1',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res5a_branch1',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 512,
#      'kernel_size': [1, 1],
#      'strides': [2, 2],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['res4b1_relu', 0, 0, {}]]]},
#    {'name': 'bn5a_branch2b',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn5a_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res5a_branch2b', 0, 0, {}]]]},
#    {'name': 'bn5a_branch1',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn5a_branch1',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res5a_branch1', 0, 0, {}]]]},
#    {'name': 'res5a',
#     'class_name': 'Add',
#     'config': {'name': 'res5a', 'trainable': True, 'dtype': 'float32'},
#     'inbound_nodes': [[['bn5a_branch2b', 0, 0, {}],
#       ['bn5a_branch1', 0, 0, {}]]]},
#    {'name': 'res5a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res5a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['res5a', 0, 0, {}]]]},
#    {'name': 'padding5b1_branch2a',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding5b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res5a_relu', 0, 0, {}]]]},
#    {'name': 'res5b1_branch2a',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res5b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 512,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding5b1_branch2a', 0, 0, {}]]]},
#    {'name': 'bn5b1_branch2a',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn5b1_branch2a',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res5b1_branch2a', 0, 0, {}]]]},
#    {'name': 'res5b1_branch2a_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res5b1_branch2a_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['bn5b1_branch2a', 0, 0, {}]]]},
#    {'name': 'padding5b1_branch2b',
#     'class_name': 'ZeroPadding2D',
#     'config': {'name': 'padding5b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'padding': [[1, 1], [1, 1]],
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res5b1_branch2a_relu', 0, 0, {}]]]},
#    {'name': 'res5b1_branch2b',
#     'class_name': 'Conv2D',
#     'config': {'name': 'res5b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'filters': 512,
#      'kernel_size': [3, 3],
#      'strides': [1, 1],
#      'padding': 'valid',
#      'data_format': 'channels_last',
#      'dilation_rate': [1, 1],
#      'activation': 'linear',
#      'use_bias': False,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 2.0,
#        'mode': 'fan_in',
#        'distribution': 'normal',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['padding5b1_branch2b', 0, 0, {}]]]},
#    {'name': 'bn5b1_branch2b',
#     'class_name': 'BatchNormalization',
#     'config': {'name': 'bn5b1_branch2b',
#      'trainable': True,
#      'dtype': 'float32',
#      'axis': 3,
#      'momentum': 0.99,
#      'epsilon': 1e-05,
#      'center': True,
#      'scale': True,
#      'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#      'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#      'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#      'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#      'beta_regularizer': None,
#      'gamma_regularizer': None,
#      'beta_constraint': None,
#      'gamma_constraint': None,
#      'freeze': False},
#     'inbound_nodes': [[['res5b1_branch2b', 0, 0, {}]]]},
#    {'name': 'res5b1',
#     'class_name': 'Add',
#     'config': {'name': 'res5b1', 'trainable': True, 'dtype': 'float32'},
#     'inbound_nodes': [[['bn5b1_branch2b', 0, 0, {}],
#       ['res5a_relu', 0, 0, {}]]]},
#    {'name': 'res5b1_relu',
#     'class_name': 'Activation',
#     'config': {'name': 'res5b1_relu',
#      'trainable': True,
#      'dtype': 'float32',
#      'activation': 'relu'},
#     'inbound_nodes': [[['res5b1', 0, 0, {}]]]},
#    {'name': 'pool5',
#     'class_name': 'GlobalAveragePooling2D',
#     'config': {'name': 'pool5',
#      'trainable': True,
#      'dtype': 'float32',
#      'data_format': 'channels_last'},
#     'inbound_nodes': [[['res5b1_relu', 0, 0, {}]]]},
#    {'name': 'fc1000',
#     'class_name': 'Dense',
#     'config': {'name': 'fc1000',
#      'trainable': True,
#      'dtype': 'float32',
#      'units': 10,
#      'activation': 'softmax',
#      'use_bias': True,
#      'kernel_initializer': {'class_name': 'VarianceScaling',
#       'config': {'scale': 1.0,
#        'mode': 'fan_avg',
#        'distribution': 'uniform',
#        'seed': None}},
#      'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#      'kernel_regularizer': None,
#      'bias_regularizer': None,
#      'activity_regularizer': None,
#      'kernel_constraint': None,
#      'bias_constraint': None},
#     'inbound_nodes': [[['pool5', 0, 0, {}]]]}],
#   'input_layers': [['input_8', 0, 0]],
#   'output_layers': [['fc1000', 0, 0]]}}

# %%
cls = globs.get(class_name)

# %%
cls.from_config(
            model_config['config'],
            custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
                                list(keras_resnet.custom_objects.items())))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-179-226e1cb8bb15> in <module>
#       2             model_config['config'],
#       3             custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# ----> 4                                 list(keras_resnet.custom_objects.items())))
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/network.py in from_config(cls, config, custom_objects)
#    1105             layer_output_tensors = layer._inbound_nodes[node_index].output_tensors
#    1106             output_tensors.append(layer_output_tensors[tensor_index])
# -> 1107         return cls(inputs=input_tensors, outputs=output_tensors, name=name)
#    1108
#    1109     def save(self, filepath, overwrite=True, include_optimizer=True):
#
# /anaconda3/lib/python3.6/site-packages/keras_resnet/models/_2d.py in __init__(self, inputs, blocks, include_top, classes, freeze_bn, *args, **kwargs)
#     149             freeze_bn=freeze_bn,
#     150             *args,
# --> 151             **kwargs
#     152         )
#     153
#
# /anaconda3/lib/python3.6/site-packages/keras_resnet/models/_2d.py in __init__(self, inputs, blocks, block, include_top, classes, freeze_bn, numerical_names, *args, **kwargs)
#      74             numerical_names = [True] * len(blocks)
#      75
# ---> 76         x = keras.layers.Conv2D(64, (7, 7), strides=(2, 2), use_bias=False, name="conv1", padding="same")(inputs)
#      77         x = keras_resnet.layers.BatchNormalization(axis=axis, epsilon=1e-5, freeze=freeze_bn, name="bn_conv1")(x)
#      78         x = keras.layers.Activation("relu", name="conv1_relu")(x)
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     487             # Actually call the layer,
#     488             # collecting output(s), mask(s), and shape(s).
# --> 489             output = self.call(inputs, **kwargs)
#     490             output_mask = self.compute_mask(inputs, previous_mask)
#     491
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/convolutional.py in call(self, inputs)
#     169                 padding=self.padding,
#     170                 data_format=self.data_format,
# --> 171                 dilation_rate=self.dilation_rate)
#     172         if self.rank == 3:
#     173             outputs = K.conv3d(
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in conv2d(x, kernel, strides, padding, data_format, dilation_rate)
#    3699     data_format = normalize_data_format(data_format)
#    3700
# -> 3701     x, tf_data_format = _preprocess_conv2d_input(x, data_format)
#    3702
#    3703     padding = _preprocess_padding(padding)
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _preprocess_conv2d_input(x, data_format, force_transpose)
#    3567     """
#    3568     # tensorflow doesn't support float64 for conv layer before 1.8.0
# -> 3569     if (dtype(x) == 'float64' and
#    3570             StrictVersion(tf.__version__.split('-')[0]) < StrictVersion('1.8.0')):
#    3571         x = tf.cast(x, 'float32')
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in dtype(x)
#     903     {{np_implementation}}
#     904     """
# --> 905     return x.dtype.base_dtype.name
#     906
#     907
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
from keras.engine.network import Network

config = model_config['config']

for layer_data in config['layers']:
    process_layer(layer_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-191-e12d046810b6> in <module>
#       4
#       5 for layer_data in config['layers']:
# ----> 6     process_layer(layer_data)
#
# NameError: name 'process_layer' is not defined

# %%
from keras.utils.generic_utils import unpack_singleton

# Layer instances created during
# the graph reconstruction process
created_layers = {}

# Dictionary mapping layer instances to
# node data that specifies a layer call.
# It acts as a queue that maintains any unprocessed
# layer call until it becomes possible to process it
# (i.e. until the input tensors to the call all exist).
unprocessed_nodes = {}

def add_unprocessed_node(layer, node_data):
    """Add node to layer list
    # Arguments
        layer: layer object
        node_data: Node data specifying layer call
    """
    if layer not in unprocessed_nodes:
        unprocessed_nodes[layer] = [node_data]
    else:
        unprocessed_nodes[layer].append(node_data)

def process_node(layer, node_data):
    """Reconstruct node by linking to inbound layers
    # Arguments
        layer: Layer to process
        node_data: List of layer configs
    # Raises
        ValueError: For incorrect layer config
        LookupError: If layer required is not found
    """
    input_tensors = []
    for input_data in node_data:
        inbound_layer_name = input_data[0]
        inbound_node_index = input_data[1]
        inbound_tensor_index = input_data[2]
        if len(input_data) == 3:
            kwargs = {}
        elif len(input_data) == 4:
            kwargs = input_data[3]
        else:
            raise ValueError('Improperly formatted model config.')
        inbound_layer = created_layers[inbound_layer_name]
        # Raise an error if the corresponding layer node
        # has not yet been created
        if len(inbound_layer._inbound_nodes) <= inbound_node_index:
            raise LookupError
        inbound_node = inbound_layer._inbound_nodes[inbound_node_index]
        input_tensors.append(
            inbound_node.output_tensors[inbound_tensor_index])

    # Call layer on its inputs, thus creating the node
    # and building the layer if needed.
    if input_tensors:
        layer(unpack_singleton(input_tensors), **kwargs)

def process_layer(layer_data):
    """Deserializes a layer, then call it on appropriate inputs.
    # Arguments
        layer_data: layer config dict.
    # Raises
        ValueError: In case of improperly formatted `layer_data` dict.
    """
    layer_name = layer_data['name']

    # Instantiate layer.
    from keras.layers import deserialize as deserialize_layer

    layer = deserialize_layer(layer_data,
                              custom_objects=custom_objects)
    created_layers[layer_name] = layer

    # Gather layer inputs.
    inbound_nodes_data = layer_data['inbound_nodes']
    for node_data in inbound_nodes_data:
        # We don't process nodes (i.e. make layer calls)
        # on the fly because the inbound node may not yet exist,
        # in case of layer shared at different topological depths
        # (e.g. a model such as A(B(A(B(x)))))
        add_unprocessed_node(layer, node_data)

# First, we create all layers and enqueue nodes to be processed
for layer_data in config['layers']:
    process_layer(layer_data)

# Then we process nodes in order of layer depth.
# Nodes that cannot yet be processed (if the inbound node
# does not yet exist) are re-enqueued, and the process
# is repeated until all nodes are processed.
while unprocessed_nodes:
    for layer_data in config['layers']:
        layer = created_layers[layer_data['name']]

        # Process all nodes in layer, if not yet processed
        if layer in unprocessed_nodes:
            node_data_list = unprocessed_nodes[layer]

            # Process nodes in order
            node_index = 0
            while node_index < len(node_data_list):
                node_data = node_data_list[node_index]
                try:
                    process_node(layer, node_data)

                # If the node does not have all inbound layers
                # available, stop processing and continue later
                except LookupError:
                    break

                node_index += 1

            # If not all nodes processed then store unprocessed nodes
            if node_index < len(node_data_list):
                unprocessed_nodes[layer] = node_data_list[node_index:]
            # If all nodes processed remove the layer
            else:
                del unprocessed_nodes[layer]

# %%
name = config.get('name')
input_tensors = []
output_tensors = []
for layer_data in config['input_layers']:
    layer_name, node_index, tensor_index = layer_data
    assert layer_name in created_layers
    layer = created_layers[layer_name]
    layer_output_tensors = layer._inbound_nodes[node_index].output_tensors
    input_tensors.append(layer_output_tensors[tensor_index])
for layer_data in config['output_layers']:
    layer_name, node_index, tensor_index = layer_data
    assert layer_name in created_layers
    layer = created_layers[layer_name]
    layer_output_tensors = layer._inbound_nodes[node_index].output_tensors
    output_tensors.append(layer_output_tensors[tensor_index])

# %%
blocks = [2, 2, 2, 2]
numerical_names = [True] * len(blocks)
axis = 3
freeze_bn = False
block = keras_resnet.blocks.basic_2d
classes=1000

# cls(inputs=input_tensors[0], outputs=output_tensors, name=name)
x = keras.layers.Conv2D(64, (7, 7), strides=(2, 2), use_bias=False, name="conv1", padding="same")(input_tensors[0])
x = keras_resnet.layers.BatchNormalization(axis=axis, epsilon=1e-5, freeze=freeze_bn, name="bn_conv1")(x)
x = keras.layers.Activation("relu", name="conv1_relu")(x)
x = keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding="same", name="pool1")(x)

features = 64

outputs = []

for stage_id, iterations in enumerate(blocks):
    for block_id in range(iterations):
        x = block(
            features,
            stage_id,
            block_id,
            numerical_name=(block_id > 0 and numerical_names[stage_id]),
            freeze_bn=freeze_bn
        )(x)

    features *= 2

    outputs.append(x)
    
x = keras.layers.GlobalAveragePooling2D(name="pool5")(x)
x = keras.layers.Dense(classes, activation="softmax", name="fc1000")(x)

keras.Model.__init__(inputs=input_tensors, outputs=outputs, name=name)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-233-9f45a073fd70> in <module>
#      33 x = keras.layers.Dense(classes, activation="softmax", name="fc1000")(x)
#      34
# ---> 35 keras.Model.__init__(inputs=input_tensors, outputs=outputs, name=name)
#
# /anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      28         def wrapper(*args, **kwargs):
#      29             if object_type == 'class':
# ---> 30                 object_name = args[0].__class__.__name__
#      31             else:
#      32                 object_name = func.__name__
#
# IndexError: tuple index out of range

# %%
x
# Out:
# <tf.Tensor 'fc1000_28/Softmax:0' shape=(?, 1000) dtype=float32>

# %%
input_tensors
# Out:
# [<tf.Tensor 'input_8_9:0' shape=(?, 28, 28, 1) dtype=float32>]

# %%
output_tensors
# Out:
# [<tf.Tensor 'fc1000_21/Softmax:0' shape=(?, 10) dtype=float32>]

# %%
model_config['config']
# Out:
# {'name': 'resnet2d18_3',
#  'layers': [{'name': 'input_8',
#    'class_name': 'InputLayer',
#    'config': {'batch_input_shape': [None, 28, 28, 1],
#     'dtype': 'float32',
#     'sparse': False,
#     'name': 'input_8'},
#    'inbound_nodes': []},
#   {'name': 'conv1',
#    'class_name': 'Conv2D',
#    'config': {'name': 'conv1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': [7, 7],
#     'strides': [2, 2],
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['input_8', 0, 0, {}]]]},
#   {'name': 'bn_conv1',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn_conv1',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['conv1', 0, 0, {}]]]},
#   {'name': 'conv1_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'conv1_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['bn_conv1', 0, 0, {}]]]},
#   {'name': 'pool1',
#    'class_name': 'MaxPooling2D',
#    'config': {'name': 'pool1',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': [3, 3],
#     'padding': 'same',
#     'strides': [2, 2],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['conv1_relu', 0, 0, {}]]]},
#   {'name': 'padding2a_branch2a',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding2a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['pool1', 0, 0, {}]]]},
#   {'name': 'res2a_branch2a',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res2a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding2a_branch2a', 0, 0, {}]]]},
#   {'name': 'bn2a_branch2a',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn2a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res2a_branch2a', 0, 0, {}]]]},
#   {'name': 'res2a_branch2a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res2a_branch2a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['bn2a_branch2a', 0, 0, {}]]]},
#   {'name': 'padding2a_branch2b',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding2a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res2a_branch2a_relu', 0, 0, {}]]]},
#   {'name': 'res2a_branch2b',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res2a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding2a_branch2b', 0, 0, {}]]]},
#   {'name': 'res2a_branch1',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res2a_branch1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': [1, 1],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['pool1', 0, 0, {}]]]},
#   {'name': 'bn2a_branch2b',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn2a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res2a_branch2b', 0, 0, {}]]]},
#   {'name': 'bn2a_branch1',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn2a_branch1',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res2a_branch1', 0, 0, {}]]]},
#   {'name': 'res2a',
#    'class_name': 'Add',
#    'config': {'name': 'res2a', 'trainable': True, 'dtype': 'float32'},
#    'inbound_nodes': [[['bn2a_branch2b', 0, 0, {}],
#      ['bn2a_branch1', 0, 0, {}]]]},
#   {'name': 'res2a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res2a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['res2a', 0, 0, {}]]]},
#   {'name': 'padding2b1_branch2a',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding2b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res2a_relu', 0, 0, {}]]]},
#   {'name': 'res2b1_branch2a',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res2b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding2b1_branch2a', 0, 0, {}]]]},
#   {'name': 'bn2b1_branch2a',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn2b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res2b1_branch2a', 0, 0, {}]]]},
#   {'name': 'res2b1_branch2a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res2b1_branch2a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['bn2b1_branch2a', 0, 0, {}]]]},
#   {'name': 'padding2b1_branch2b',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding2b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res2b1_branch2a_relu', 0, 0, {}]]]},
#   {'name': 'res2b1_branch2b',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res2b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding2b1_branch2b', 0, 0, {}]]]},
#   {'name': 'bn2b1_branch2b',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn2b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res2b1_branch2b', 0, 0, {}]]]},
#   {'name': 'res2b1',
#    'class_name': 'Add',
#    'config': {'name': 'res2b1', 'trainable': True, 'dtype': 'float32'},
#    'inbound_nodes': [[['bn2b1_branch2b', 0, 0, {}],
#      ['res2a_relu', 0, 0, {}]]]},
#   {'name': 'res2b1_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res2b1_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['res2b1', 0, 0, {}]]]},
#   {'name': 'padding3a_branch2a',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding3a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res2b1_relu', 0, 0, {}]]]},
#   {'name': 'res3a_branch2a',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res3a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': [3, 3],
#     'strides': [2, 2],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding3a_branch2a', 0, 0, {}]]]},
#   {'name': 'bn3a_branch2a',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn3a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res3a_branch2a', 0, 0, {}]]]},
#   {'name': 'res3a_branch2a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res3a_branch2a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['bn3a_branch2a', 0, 0, {}]]]},
#   {'name': 'padding3a_branch2b',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding3a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res3a_branch2a_relu', 0, 0, {}]]]},
#   {'name': 'res3a_branch2b',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res3a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding3a_branch2b', 0, 0, {}]]]},
#   {'name': 'res3a_branch1',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res3a_branch1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': [1, 1],
#     'strides': [2, 2],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['res2b1_relu', 0, 0, {}]]]},
#   {'name': 'bn3a_branch2b',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn3a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res3a_branch2b', 0, 0, {}]]]},
#   {'name': 'bn3a_branch1',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn3a_branch1',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res3a_branch1', 0, 0, {}]]]},
#   {'name': 'res3a',
#    'class_name': 'Add',
#    'config': {'name': 'res3a', 'trainable': True, 'dtype': 'float32'},
#    'inbound_nodes': [[['bn3a_branch2b', 0, 0, {}],
#      ['bn3a_branch1', 0, 0, {}]]]},
#   {'name': 'res3a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res3a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['res3a', 0, 0, {}]]]},
#   {'name': 'padding3b1_branch2a',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding3b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res3a_relu', 0, 0, {}]]]},
#   {'name': 'res3b1_branch2a',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res3b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding3b1_branch2a', 0, 0, {}]]]},
#   {'name': 'bn3b1_branch2a',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn3b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res3b1_branch2a', 0, 0, {}]]]},
#   {'name': 'res3b1_branch2a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res3b1_branch2a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['bn3b1_branch2a', 0, 0, {}]]]},
#   {'name': 'padding3b1_branch2b',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding3b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res3b1_branch2a_relu', 0, 0, {}]]]},
#   {'name': 'res3b1_branch2b',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res3b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 128,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding3b1_branch2b', 0, 0, {}]]]},
#   {'name': 'bn3b1_branch2b',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn3b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res3b1_branch2b', 0, 0, {}]]]},
#   {'name': 'res3b1',
#    'class_name': 'Add',
#    'config': {'name': 'res3b1', 'trainable': True, 'dtype': 'float32'},
#    'inbound_nodes': [[['bn3b1_branch2b', 0, 0, {}],
#      ['res3a_relu', 0, 0, {}]]]},
#   {'name': 'res3b1_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res3b1_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['res3b1', 0, 0, {}]]]},
#   {'name': 'padding4a_branch2a',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding4a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res3b1_relu', 0, 0, {}]]]},
#   {'name': 'res4a_branch2a',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res4a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 256,
#     'kernel_size': [3, 3],
#     'strides': [2, 2],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding4a_branch2a', 0, 0, {}]]]},
#   {'name': 'bn4a_branch2a',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn4a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res4a_branch2a', 0, 0, {}]]]},
#   {'name': 'res4a_branch2a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res4a_branch2a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['bn4a_branch2a', 0, 0, {}]]]},
#   {'name': 'padding4a_branch2b',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding4a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res4a_branch2a_relu', 0, 0, {}]]]},
#   {'name': 'res4a_branch2b',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res4a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 256,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding4a_branch2b', 0, 0, {}]]]},
#   {'name': 'res4a_branch1',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res4a_branch1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 256,
#     'kernel_size': [1, 1],
#     'strides': [2, 2],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['res3b1_relu', 0, 0, {}]]]},
#   {'name': 'bn4a_branch2b',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn4a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res4a_branch2b', 0, 0, {}]]]},
#   {'name': 'bn4a_branch1',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn4a_branch1',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res4a_branch1', 0, 0, {}]]]},
#   {'name': 'res4a',
#    'class_name': 'Add',
#    'config': {'name': 'res4a', 'trainable': True, 'dtype': 'float32'},
#    'inbound_nodes': [[['bn4a_branch2b', 0, 0, {}],
#      ['bn4a_branch1', 0, 0, {}]]]},
#   {'name': 'res4a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res4a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['res4a', 0, 0, {}]]]},
#   {'name': 'padding4b1_branch2a',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding4b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res4a_relu', 0, 0, {}]]]},
#   {'name': 'res4b1_branch2a',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res4b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 256,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding4b1_branch2a', 0, 0, {}]]]},
#   {'name': 'bn4b1_branch2a',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn4b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res4b1_branch2a', 0, 0, {}]]]},
#   {'name': 'res4b1_branch2a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res4b1_branch2a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['bn4b1_branch2a', 0, 0, {}]]]},
#   {'name': 'padding4b1_branch2b',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding4b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res4b1_branch2a_relu', 0, 0, {}]]]},
#   {'name': 'res4b1_branch2b',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res4b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 256,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding4b1_branch2b', 0, 0, {}]]]},
#   {'name': 'bn4b1_branch2b',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn4b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res4b1_branch2b', 0, 0, {}]]]},
#   {'name': 'res4b1',
#    'class_name': 'Add',
#    'config': {'name': 'res4b1', 'trainable': True, 'dtype': 'float32'},
#    'inbound_nodes': [[['bn4b1_branch2b', 0, 0, {}],
#      ['res4a_relu', 0, 0, {}]]]},
#   {'name': 'res4b1_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res4b1_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['res4b1', 0, 0, {}]]]},
#   {'name': 'padding5a_branch2a',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding5a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res4b1_relu', 0, 0, {}]]]},
#   {'name': 'res5a_branch2a',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res5a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 512,
#     'kernel_size': [3, 3],
#     'strides': [2, 2],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding5a_branch2a', 0, 0, {}]]]},
#   {'name': 'bn5a_branch2a',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn5a_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res5a_branch2a', 0, 0, {}]]]},
#   {'name': 'res5a_branch2a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res5a_branch2a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['bn5a_branch2a', 0, 0, {}]]]},
#   {'name': 'padding5a_branch2b',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding5a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res5a_branch2a_relu', 0, 0, {}]]]},
#   {'name': 'res5a_branch2b',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res5a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 512,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding5a_branch2b', 0, 0, {}]]]},
#   {'name': 'res5a_branch1',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res5a_branch1',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 512,
#     'kernel_size': [1, 1],
#     'strides': [2, 2],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['res4b1_relu', 0, 0, {}]]]},
#   {'name': 'bn5a_branch2b',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn5a_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res5a_branch2b', 0, 0, {}]]]},
#   {'name': 'bn5a_branch1',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn5a_branch1',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res5a_branch1', 0, 0, {}]]]},
#   {'name': 'res5a',
#    'class_name': 'Add',
#    'config': {'name': 'res5a', 'trainable': True, 'dtype': 'float32'},
#    'inbound_nodes': [[['bn5a_branch2b', 0, 0, {}],
#      ['bn5a_branch1', 0, 0, {}]]]},
#   {'name': 'res5a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res5a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['res5a', 0, 0, {}]]]},
#   {'name': 'padding5b1_branch2a',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding5b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res5a_relu', 0, 0, {}]]]},
#   {'name': 'res5b1_branch2a',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res5b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 512,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding5b1_branch2a', 0, 0, {}]]]},
#   {'name': 'bn5b1_branch2a',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn5b1_branch2a',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res5b1_branch2a', 0, 0, {}]]]},
#   {'name': 'res5b1_branch2a_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res5b1_branch2a_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['bn5b1_branch2a', 0, 0, {}]]]},
#   {'name': 'padding5b1_branch2b',
#    'class_name': 'ZeroPadding2D',
#    'config': {'name': 'padding5b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'padding': [[1, 1], [1, 1]],
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res5b1_branch2a_relu', 0, 0, {}]]]},
#   {'name': 'res5b1_branch2b',
#    'class_name': 'Conv2D',
#    'config': {'name': 'res5b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 512,
#     'kernel_size': [3, 3],
#     'strides': [1, 1],
#     'padding': 'valid',
#     'data_format': 'channels_last',
#     'dilation_rate': [1, 1],
#     'activation': 'linear',
#     'use_bias': False,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'normal',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['padding5b1_branch2b', 0, 0, {}]]]},
#   {'name': 'bn5b1_branch2b',
#    'class_name': 'BatchNormalization',
#    'config': {'name': 'bn5b1_branch2b',
#     'trainable': True,
#     'dtype': 'float32',
#     'axis': 3,
#     'momentum': 0.99,
#     'epsilon': 1e-05,
#     'center': True,
#     'scale': True,
#     'beta_initializer': {'class_name': 'Zeros', 'config': {}},
#     'gamma_initializer': {'class_name': 'Ones', 'config': {}},
#     'moving_mean_initializer': {'class_name': 'Zeros', 'config': {}},
#     'moving_variance_initializer': {'class_name': 'Ones', 'config': {}},
#     'beta_regularizer': None,
#     'gamma_regularizer': None,
#     'beta_constraint': None,
#     'gamma_constraint': None,
#     'freeze': False},
#    'inbound_nodes': [[['res5b1_branch2b', 0, 0, {}]]]},
#   {'name': 'res5b1',
#    'class_name': 'Add',
#    'config': {'name': 'res5b1', 'trainable': True, 'dtype': 'float32'},
#    'inbound_nodes': [[['bn5b1_branch2b', 0, 0, {}],
#      ['res5a_relu', 0, 0, {}]]]},
#   {'name': 'res5b1_relu',
#    'class_name': 'Activation',
#    'config': {'name': 'res5b1_relu',
#     'trainable': True,
#     'dtype': 'float32',
#     'activation': 'relu'},
#    'inbound_nodes': [[['res5b1', 0, 0, {}]]]},
#   {'name': 'pool5',
#    'class_name': 'GlobalAveragePooling2D',
#    'config': {'name': 'pool5',
#     'trainable': True,
#     'dtype': 'float32',
#     'data_format': 'channels_last'},
#    'inbound_nodes': [[['res5b1_relu', 0, 0, {}]]]},
#   {'name': 'fc1000',
#    'class_name': 'Dense',
#    'config': {'name': 'fc1000',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 10,
#     'activation': 'softmax',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'inbound_nodes': [[['pool5', 0, 0, {}]]]}],
#  'input_layers': [['input_8', 0, 0]],
#  'output_layers': [['fc1000', 0, 0]]}

# %%
from keras.utils import CustomObjectScope
from keras_resnet.models import ResNet2D18

with CustomObjectScope({'BatchNormalization': keras_resnet.layers._batch_normalization.BatchNormalization}):
#     model = load_model('./saved_models/test.h5', custom_objects=keras_resnet.custom_objects)
    model = load_model('./saved_models/test.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-fa30982c29ae> in <module>
#       4 with CustomObjectScope({'BatchNormalization': keras_resnet.layers._batch_normalization.BatchNormalization}):
#       5 #     model = load_model('./saved_models/test.h5', custom_objects=keras_resnet.custom_objects)
# ----> 6     model = load_model('./saved_models/test.h5')
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in _deserialize_model(h5dict, custom_objects, compile)
#     272         raise ValueError('No model found in config.')
#     273     model_config = json.loads(model_config.decode('utf-8'))
# --> 274     model = model_from_config(model_config, custom_objects=custom_objects)
#     275     model_weights_group = h5dict['model_weights']
#     276
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in model_from_config(config, custom_objects)
#     625                         '`Sequential.from_config(config)`?')
#     626     from ..layers import deserialize
# --> 627     return deserialize(config, custom_objects=custom_objects)
#     628
#     629
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/__init__.py in deserialize(config, custom_objects)
#     166                                     module_objects=globs,
#     167                                     custom_objects=custom_objects,
# --> 168                                     printable_module_name='layer')
#
# /anaconda3/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     138             if cls is None:
#     139                 raise ValueError('Unknown ' + printable_module_name +
# --> 140                                  ': ' + class_name)
#     141         if hasattr(cls, 'from_config'):
#     142             custom_objects = custom_objects or {}
#
# ValueError: Unknown layer: ResNet2D18

# %%
shift_reductor_model.summary()
# Out:
# Model: "resnet2d18_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 14, 14, 64)   3136        input_8[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 14, 14, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 14, 14, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 7, 7, 64)     0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# padding2a_branch2a (ZeroPadding (None, 9, 9, 64)     0           pool1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 7, 7, 64)     36864       padding2a_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_relu (Activation (None, 7, 7, 64)     0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2a_branch2b (ZeroPadding (None, 9, 9, 64)     0           res2a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 7, 7, 64)     36864       padding2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 7, 7, 64)     4096        pool1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 7, 7, 64)     256         res2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a (Add)                     (None, 7, 7, 64)     0           bn2a_branch2b[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# res2a_relu (Activation)         (None, 7, 7, 64)     0           res2a[0][0]
# __________________________________________________________________________________________________
# padding2b1_branch2a (ZeroPaddin (None, 9, 9, 64)     0           res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b1_branch2a (Conv2D)        (None, 7, 7, 64)     36864       padding2b1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn2b1_branch2a (BatchNormalizat (None, 7, 7, 64)     256         res2b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b1_branch2a_relu (Activatio (None, 7, 7, 64)     0           bn2b1_branch2a[0][0]
# __________________________________________________________________________________________________
# padding2b1_branch2b (ZeroPaddin (None, 9, 9, 64)     0           res2b1_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b1_branch2b (Conv2D)        (None, 7, 7, 64)     36864       padding2b1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn2b1_branch2b (BatchNormalizat (None, 7, 7, 64)     256         res2b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b1 (Add)                    (None, 7, 7, 64)     0           bn2b1_branch2b[0][0]
#                                                                  res2a_relu[0][0]
# __________________________________________________________________________________________________
# res2b1_relu (Activation)        (None, 7, 7, 64)     0           res2b1[0][0]
# __________________________________________________________________________________________________
# padding3a_branch2a (ZeroPadding (None, 9, 9, 64)     0           res2b1_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 4, 4, 128)    73728       padding3a_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_relu (Activation (None, 4, 4, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3a_branch2b (ZeroPadding (None, 6, 6, 128)    0           res3a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 4, 4, 128)    147456      padding3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 4, 4, 128)    8192        res2b1_relu[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 4, 4, 128)    512         res3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a (Add)                     (None, 4, 4, 128)    0           bn3a_branch2b[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# res3a_relu (Activation)         (None, 4, 4, 128)    0           res3a[0][0]
# __________________________________________________________________________________________________
# padding3b1_branch2a (ZeroPaddin (None, 6, 6, 128)    0           res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2a (Conv2D)        (None, 4, 4, 128)    147456      padding3b1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2a (BatchNormalizat (None, 4, 4, 128)    512         res3b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2a_relu (Activatio (None, 4, 4, 128)    0           bn3b1_branch2a[0][0]
# __________________________________________________________________________________________________
# padding3b1_branch2b (ZeroPaddin (None, 6, 6, 128)    0           res3b1_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res3b1_branch2b (Conv2D)        (None, 4, 4, 128)    147456      padding3b1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn3b1_branch2b (BatchNormalizat (None, 4, 4, 128)    512         res3b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b1 (Add)                    (None, 4, 4, 128)    0           bn3b1_branch2b[0][0]
#                                                                  res3a_relu[0][0]
# __________________________________________________________________________________________________
# res3b1_relu (Activation)        (None, 4, 4, 128)    0           res3b1[0][0]
# __________________________________________________________________________________________________
# padding4a_branch2a (ZeroPadding (None, 6, 6, 128)    0           res3b1_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 2, 2, 256)    294912      padding4a_branch2a[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 2, 2, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_relu (Activation (None, 2, 2, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4a_branch2b (ZeroPadding (None, 4, 4, 256)    0           res4a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 2, 2, 256)    589824      padding4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 2, 2, 256)    32768       res3b1_relu[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 2, 2, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 2, 2, 256)    1024        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a (Add)                     (None, 2, 2, 256)    0           bn4a_branch2b[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# res4a_relu (Activation)         (None, 2, 2, 256)    0           res4a[0][0]
# __________________________________________________________________________________________________
# padding4b1_branch2a (ZeroPaddin (None, 4, 4, 256)    0           res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b1_branch2a (Conv2D)        (None, 2, 2, 256)    589824      padding4b1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn4b1_branch2a (BatchNormalizat (None, 2, 2, 256)    1024        res4b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b1_branch2a_relu (Activatio (None, 2, 2, 256)    0           bn4b1_branch2a[0][0]
# __________________________________________________________________________________________________
# padding4b1_branch2b (ZeroPaddin (None, 4, 4, 256)    0           res4b1_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res4b1_branch2b (Conv2D)        (None, 2, 2, 256)    589824      padding4b1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn4b1_branch2b (BatchNormalizat (None, 2, 2, 256)    1024        res4b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b1 (Add)                    (None, 2, 2, 256)    0           bn4b1_branch2b[0][0]
#                                                                  res4a_relu[0][0]
# __________________________________________________________________________________________________
# res4b1_relu (Activation)        (None, 2, 2, 256)    0           res4b1[0][0]
# __________________________________________________________________________________________________
# padding5a_branch2a (ZeroPadding (None, 4, 4, 256)    0           res4b1_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 1, 1, 512)    1179648     padding5a_branch2a[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 1, 1, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_relu (Activation (None, 1, 1, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5a_branch2b (ZeroPadding (None, 3, 3, 512)    0           res5a_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 1, 1, 512)    2359296     padding5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 1, 1, 512)    131072      res4b1_relu[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 1, 1, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 1, 1, 512)    2048        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a (Add)                     (None, 1, 1, 512)    0           bn5a_branch2b[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# res5a_relu (Activation)         (None, 1, 1, 512)    0           res5a[0][0]
# __________________________________________________________________________________________________
# padding5b1_branch2a (ZeroPaddin (None, 3, 3, 512)    0           res5a_relu[0][0]
# __________________________________________________________________________________________________
# res5b1_branch2a (Conv2D)        (None, 1, 1, 512)    2359296     padding5b1_branch2a[0][0]
# __________________________________________________________________________________________________
# bn5b1_branch2a (BatchNormalizat (None, 1, 1, 512)    2048        res5b1_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b1_branch2a_relu (Activatio (None, 1, 1, 512)    0           bn5b1_branch2a[0][0]
# __________________________________________________________________________________________________
# padding5b1_branch2b (ZeroPaddin (None, 3, 3, 512)    0           res5b1_branch2a_relu[0][0]
# __________________________________________________________________________________________________
# res5b1_branch2b (Conv2D)        (None, 1, 1, 512)    2359296     padding5b1_branch2b[0][0]
# __________________________________________________________________________________________________
# bn5b1_branch2b (BatchNormalizat (None, 1, 1, 512)    2048        res5b1_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b1 (Add)                    (None, 1, 1, 512)    0           bn5b1_branch2b[0][0]
#                                                                  res5a_relu[0][0]
# __________________________________________________________________________________________________
# res5b1_relu (Activation)        (None, 1, 1, 512)    0           res5b1[0][0]
# __________________________________________________________________________________________________
# pool5 (GlobalAveragePooling2D)  (None, 512)          0           res5b1_relu[0][0]
# __________________________________________________________________________________________________
# fc1000 (Dense)                  (None, 10)           5130        pool5[0][0]
# ==================================================================================================
# Total params: 11,189,322
# Trainable params: 11,179,594
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %%
# Detect shift
shift_detector = ShiftDetector(dr_techniques, test_types, od_tests, md_tests, sign_level, red_models, sample, datset)
(od_decs, ind_od_decs, ind_od_p_vals), (md_decs, ind_md_decs, ind_md_p_vals), red_dim, red_models, val_acc, te_acc = shift_detector.detect_data_shift(X_tr_3, y_tr_3, X_val_3, y_val_3, X_te_3, y_te_3, orig_dims, nb_classes)
# Out:
# NoRed
# PCA
# SRP
# UAE
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# TAE
# BBSDs
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/2
# 50000/50000 [==============================] - 591s 12ms/step - loss: 0.2496 - accuracy: 0.9222 - val_loss: 0.2623 - val_accuracy: 0.9224
# Epoch 2/2
# 50000/50000 [==============================] - 582s 12ms/step - loss: 0.0477 - accuracy: 0.9856 - val_loss: 0.0644 - val_accuracy: 0.9800
# BBSDh
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-6a449994c698> in <module>
#       1 # Detect shift
#       2 shift_detector = ShiftDetector(dr_techniques, test_types, od_tests, md_tests, sign_level, red_models, sample, datset)
# ----> 3 (od_decs, ind_od_decs, ind_od_p_vals), (md_decs, ind_md_decs, ind_md_p_vals), red_dim, red_models, val_acc, te_acc = shift_detector.detect_data_shift(X_tr_3, y_tr_3, X_val_3, y_val_3, X_te_3, y_te_3, orig_dims, nb_classes)
#
# ~/Documents/New Volume/courses/lab/projects/medshifts/failing-loudly/shift_detector.py in detect_data_shift(self, X_tr, y_tr, X_val, y_val, X_te, y_te, orig_dims, nb_classes)
#      54             shift_reductor_model = None
#      55             if self.red_models[dr_ind] is None:
# ---> 56                 shift_reductor_model = shift_reductor.fit_reductor()
#      57                 self.red_models[dr_ind] = shift_reductor_model
#      58             else:
#
# ~/Documents/New Volume/courses/lab/projects/medshifts/failing-loudly/shift_reductor.py in fit_reductor(self)
#      74             self.mod_path = './saved_models/' + self.datset + '_standard_class_model.h5'
#      75             if os.path.exists(self.mod_path):
# ---> 76                 return load_model(self.mod_path, custom_objects=keras_resnet.custom_objects)
#      77             return self.neural_network_classifier(train=True)
#      78
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in _deserialize_model(h5dict, custom_objects, compile)
#     272         raise ValueError('No model found in config.')
#     273     model_config = json.loads(model_config.decode('utf-8'))
# --> 274     model = model_from_config(model_config, custom_objects=custom_objects)
#     275     model_weights_group = h5dict['model_weights']
#     276
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in model_from_config(config, custom_objects)
#     625                         '`Sequential.from_config(config)`?')
#     626     from ..layers import deserialize
# --> 627     return deserialize(config, custom_objects=custom_objects)
#     628
#     629
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/__init__.py in deserialize(config, custom_objects)
#     166                                     module_objects=globs,
#     167                                     custom_objects=custom_objects,
# --> 168                                     printable_module_name='layer')
#
# /anaconda3/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     138             if cls is None:
#     139                 raise ValueError('Unknown ' + printable_module_name +
# --> 140                                  ': ' + class_name)
#     141         if hasattr(cls, 'from_config'):
#     142             custom_objects = custom_objects or {}
#
# ValueError: Unknown layer: ResNet2D18

# %%
import importlib
importlib.reload(keras_resnet)
# Out:
# <module 'keras_resnet' from '/anaconda3/lib/python3.6/site-packages/keras_resnet/__init__.py'>

# %%
keras_resnet.custom_objects
# Out:
# {'BatchNormalization': keras_resnet.layers._batch_normalization.BatchNormalization,
#  'ResNet2D18': keras_resnet.models._2d.ResNet2D18}

# %%
a=keras_resnet.custom_objects
a['ResNet2D18'] = ResNet2D18

# %%
keras.layers.Input(orig_dims).dtype
# Out:
# tf.float32

# %%
from keras_resnet.models import ResNet2D18

# %%
mod_path='./saved_models/mnist_standard_class_model.h5'
load_model(mod_path, custom_objects=keras_resnet.custom_objects)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-c76834ea53da> in <module>
#       1 mod_path='./saved_models/mnist_standard_class_model.h5'
# ----> 2 load_model(mod_path, custom_objects=keras_resnet.custom_objects)
#       3 # load_model(mod_path, custom_objects={'ResNet2D18': keras_resnet.models._2d.ResNet2D18})
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in _deserialize_model(h5dict, custom_objects, compile)
#     272         raise ValueError('No model found in config.')
#     273     model_config = json.loads(model_config.decode('utf-8'))
# --> 274     model = model_from_config(model_config, custom_objects=custom_objects)
#     275     model_weights_group = h5dict['model_weights']
#     276
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/saving.py in model_from_config(config, custom_objects)
#     625                         '`Sequential.from_config(config)`?')
#     626     from ..layers import deserialize
# --> 627     return deserialize(config, custom_objects=custom_objects)
#     628
#     629
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/__init__.py in deserialize(config, custom_objects)
#     166                                     module_objects=globs,
#     167                                     custom_objects=custom_objects,
# --> 168                                     printable_module_name='layer')
#
# /anaconda3/lib/python3.6/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     145                     config['config'],
#     146                     custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 147                                         list(custom_objects.items())))
#     148             with CustomObjectScope(custom_objects):
#     149                 return cls.from_config(config['config'])
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/network.py in from_config(cls, config, custom_objects)
#    1105             layer_output_tensors = layer._inbound_nodes[node_index].output_tensors
#    1106             output_tensors.append(layer_output_tensors[tensor_index])
# -> 1107         return cls(inputs=input_tensors, outputs=output_tensors, name=name)
#    1108
#    1109     def save(self, filepath, overwrite=True, include_optimizer=True):
#
# /anaconda3/lib/python3.6/site-packages/keras_resnet/models/_2d.py in __init__(self, inputs, blocks, include_top, classes, freeze_bn, *args, **kwargs)
#     149             freeze_bn=freeze_bn,
#     150             *args,
# --> 151             **kwargs
#     152         )
#     153
#
# /anaconda3/lib/python3.6/site-packages/keras_resnet/models/_2d.py in __init__(self, inputs, blocks, block, include_top, classes, freeze_bn, numerical_names, *args, **kwargs)
#      74             numerical_names = [True] * len(blocks)
#      75
# ---> 76         x = keras.layers.Conv2D(64, (7, 7), strides=(2, 2), use_bias=False, name="conv1", padding="same")(inputs)
#      77         x = keras_resnet.layers.BatchNormalization(axis=axis, epsilon=1e-5, freeze=freeze_bn, name="bn_conv1")(x)
#      78         x = keras.layers.Activation("relu", name="conv1_relu")(x)
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     487             # Actually call the layer,
#     488             # collecting output(s), mask(s), and shape(s).
# --> 489             output = self.call(inputs, **kwargs)
#     490             output_mask = self.compute_mask(inputs, previous_mask)
#     491
#
# /anaconda3/lib/python3.6/site-packages/keras/layers/convolutional.py in call(self, inputs)
#     169                 padding=self.padding,
#     170                 data_format=self.data_format,
# --> 171                 dilation_rate=self.dilation_rate)
#     172         if self.rank == 3:
#     173             outputs = K.conv3d(
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in conv2d(x, kernel, strides, padding, data_format, dilation_rate)
#    3699     data_format = normalize_data_format(data_format)
#    3700
# -> 3701     x, tf_data_format = _preprocess_conv2d_input(x, data_format)
#    3702
#    3703     padding = _preprocess_padding(padding)
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _preprocess_conv2d_input(x, data_format, force_transpose)
#    3567     """
#    3568     # tensorflow doesn't support float64 for conv layer before 1.8.0
# -> 3569     if (dtype(x) == 'float64' and
#    3570             StrictVersion(tf.__version__.split('-')[0]) < StrictVersion('1.8.0')):
#    3571         x = tf.cast(x, 'float32')
#
# /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in dtype(x)
#     903     {{np_implementation}}
#     904     """
# --> 905     return x.dtype.base_dtype.name
#     906
#     907
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
X_te_orig.shape
# Out:
# (10000, 784)

# %%
# -------------------------------------------------
# PIPELINE START
# -------------------------------------------------

samples_shifts_rands_dr_tech = np.ones((len(samples), len(shifts), random_runs, len(dr_techniques) + 1)) * (-1)

red_dim = -1
red_models = [None] * len(DimensionalityReduction)

for shift_idx, shift in enumerate(shifts):

    shift_path = path + shift + '/'
    if not os.path.exists(shift_path):
        os.makedirs(shift_path)

    rand_run_p_vals = np.ones((len(samples), len(dr_techniques) + 1, random_runs)) * (-1)

    for rand_run in range(random_runs):

        print("Random run %s" % rand_run)

        rand_run_path = shift_path + str(rand_run) + '/'
        if not os.path.exists(rand_run_path):
            os.makedirs(rand_run_path)

        np.random.seed(rand_run)
        set_random_seed(rand_run)

        # Load data
        (X_tr_orig, y_tr_orig), (X_val_orig, y_val_orig), (X_te_orig, y_te_orig), orig_dims, nb_classes = import_dataset(datset, shuffle=True)
        X_tr_orig = normalize_datapoints(X_tr_orig, 255.)
        X_te_orig = normalize_datapoints(X_te_orig, 255.)
        X_val_orig = normalize_datapoints(X_val_orig, 255.)

        # Apply shift
        if shift == 'orig':
            print('Original')
            (X_tr_orig, y_tr_orig), (X_val_orig, y_val_orig), (X_te_orig, y_te_orig), orig_dims, nb_classes = import_dataset(datset)
            X_tr_orig = normalize_datapoints(X_tr_orig, 255.)
            X_te_orig = normalize_datapoints(X_te_orig, 255.)
            X_val_orig = normalize_datapoints(X_val_orig, 255.)
            X_te_1 = X_te_orig.copy()
            y_te_1 = y_te_orig.copy()
        else:
            (X_te_1, y_te_1) = apply_shift(X_te_orig, y_te_orig, shift, orig_dims, datset)

        X_te_2 , y_te_2 = random_shuffle(X_te_1, y_te_1)

        # Check detection performance for different numbers of samples from test
        for si, sample in enumerate(samples):

            print("Sample %s" % sample)

            sample_path = rand_run_path + str(sample) + '/'
            if not os.path.exists(sample_path):
                os.makedirs(sample_path)

            X_te_3 = X_te_2[:sample,:]
            x_te_3_samp = X_te_3[0]
            y_te_3 = y_te_2[:sample]

            if test_type == 'multiv':
                X_val_3 = X_val_orig[:1000,:]
                y_val_3 = y_val_orig[:1000]
            else:
                X_val_3 = np.copy(X_val_orig)
                y_val_3 = np.copy(y_val_orig)

            X_tr_3 = np.copy(X_tr_orig)
            y_tr_3 = np.copy(y_tr_orig)

            # Detect shift
            shift_detector = ShiftDetector(dr_techniques, test_types, od_tests, md_tests, sign_level, red_models, sample, datset)
            (od_decs, ind_od_decs, ind_od_p_vals), (md_decs, ind_md_decs, ind_md_p_vals), red_dim, red_models, val_acc, te_acc = shift_detector.detect_data_shift(X_tr_3, y_tr_3, X_val_3, y_val_3, X_te_3, y_te_3, orig_dims, nb_classes)

            if test_type == 'multiv':
                print("Shift decision: ", ind_md_decs.flatten())
                print("Shift p-vals: ", ind_md_p_vals.flatten())

                rand_run_p_vals[si,:,rand_run] = ind_md_p_vals.flatten()
            else:
                print("Shift decision: ", ind_od_decs.flatten())
                print("Shift p-vals: ", ind_od_p_vals.flatten())

                # Characterize shift via difference classifier
                shift_locator = ShiftLocator(orig_dims, dc=DifferenceClassifier.FFNNDCL, sign_level=sign_level)
                model, score, (X_tr_dcl, y_tr_dcl, X_te_dcl, y_te_dcl) = shift_locator.build_model(X_tr_3, X_te_3)
                test_indices, test_perc, dec, p_val = shift_locator.most_likely_shifted_samples(model, X_te_dcl, y_te_dcl)

                rand_run_p_vals[si,:,rand_run] = np.append(ind_od_p_vals.flatten(), p_val)

                if datset == 'mnist' or datset == 'mnist_usps' or datset == 'mnist_usps':
                    samp_shape = (28,28)
                    cmap = 'gray'
                elif datset == 'cifar10' or datset == 'svhn':
                    samp_shape = (32,32,3)
                    cmap = None
                
                if dec:
                    most_conf_test_indices = test_indices[test_perc > 0.8]

                    top_same_samples_path = sample_path + 'top_same'
                    if not os.path.exists(top_same_samples_path):
                        os.makedirs(top_same_samples_path)

                    rev_top_test_ind = test_indices[::-1][:difference_samples]
                    least_conf_samples = X_te_dcl[rev_top_test_ind]
                    for j in range(len(rev_top_test_ind)):
                        samp = least_conf_samples[j, :]
                        fig = plt.imshow(samp.reshape(samp_shape), cmap=cmap)
                        plt.axis('off')
                        fig.axes.get_xaxis().set_visible(False)
                        fig.axes.get_yaxis().set_visible(False)
                        plt.savefig("%s/%s.pdf" % (top_same_samples_path, j), bbox_inches='tight', pad_inches=0)
                        plt.clf()

                        j = j + 1

                    top_different_samples_path = sample_path + 'top_diff'
                    if not os.path.exists(top_different_samples_path):
                        os.makedirs(top_different_samples_path)

                    most_conf_samples = X_te_dcl[most_conf_test_indices]
                    original_indices = []
                    j = 0
                    for i in range(len(most_conf_samples)):
                        samp = most_conf_samples[i,:]
                        ind = np.where(np.all(X_te_3==samp,axis=1))
                        if len(ind[0]) > 0:
                            original_indices.append(np.asscalar(ind[0]))

                            if j < difference_samples:
                                fig = plt.imshow(samp.reshape(samp_shape), cmap=cmap)
                                plt.axis('off')
                                fig.axes.get_xaxis().set_visible(False)
                                fig.axes.get_yaxis().set_visible(False)
                                plt.savefig("%s/%s.pdf" % (top_different_samples_path,j), bbox_inches='tight', pad_inches = 0)
                                plt.clf()

                                j = j + 1

        for dr_idx, dr in enumerate(dr_techniques_plot):
            plt.semilogx(np.array(samples), rand_run_p_vals[:,dr_idx,rand_run], format[dr], color=colors[dr], label="%s" % DimensionalityReduction(dr).name)
        plt.axhline(y=sign_level, color='k')
        plt.xlabel('Number of samples from test')
        plt.ylabel('$p$-value')
        plt.savefig("%s/dr_sample_comp_noleg.pdf" % rand_run_path, bbox_inches='tight')
        plt.legend()
        plt.savefig("%s/dr_sample_comp.pdf" % rand_run_path, bbox_inches='tight')
        plt.clf()

        np.savetxt("%s/dr_method_p_vals.csv" % rand_run_path, rand_run_p_vals[:,:,rand_run], delimiter=",")

        np.random.seed(seed)
        set_random_seed(seed)

    mean_p_vals = np.mean(rand_run_p_vals, axis=2)
    std_p_vals = np.std(rand_run_p_vals, axis=2)

    for dr_idx, dr in enumerate(dr_techniques_plot):
        errorfill(np.array(samples), mean_p_vals[:,dr_idx], std_p_vals[:,dr_idx], fmt=format[dr], color=colors[dr], label="%s" % DimensionalityReduction(dr).name)
    plt.axhline(y=sign_level, color='k')
    plt.xlabel('Number of samples from test')
    plt.ylabel('$p$-value')
    plt.savefig("%s/dr_sample_comp_noleg.pdf" % shift_path, bbox_inches='tight')
    plt.legend()
    plt.savefig("%s/dr_sample_comp.pdf" % shift_path, bbox_inches='tight')
    plt.clf()

    for dr_idx, dr in enumerate(dr_techniques_plot):
        errorfill(np.array(samples), mean_p_vals[:,dr_idx], std_p_vals[:,dr_idx], fmt=format[dr], color=colors[dr])
        plt.xlabel('Number of samples from test')
        plt.ylabel('$p$-value')
        plt.axhline(y=sign_level, color='k', label='sign_level')
        plt.savefig("%s/%s_conf.pdf" % (shift_path, DimensionalityReduction(dr).name), bbox_inches='tight')
        plt.clf()

    np.savetxt("%s/mean_p_vals.csv" % shift_path, mean_p_vals, delimiter=",")
    np.savetxt("%s/std_p_vals.csv" % shift_path, std_p_vals, delimiter=",")

    for dr_idx, dr in enumerate(dr_techniques_plot):
        samples_shifts_rands_dr_tech[:,shift_idx,:,dr_idx] = rand_run_p_vals[:,dr_idx,:]

    np.save("%s/samples_shifts_rands_dr_tech.npy" % (path), samples_shifts_rands_dr_tech)

for dr_idx, dr in enumerate(dr_techniques_plot):
    dr_method_results = samples_shifts_rands_dr_tech[:,:,:,dr_idx]

    mean_p_vals = np.mean(dr_method_results, axis=2)
    std_p_vals = np.std(dr_method_results, axis=2)

    for idx, shift in enumerate(shifts):
        errorfill(np.array(samples), mean_p_vals[:, idx], std_p_vals[:, idx], fmt=linestyles[idx]+markers[dr], color=colorscale(colors[dr],brightness[idx]), label="%s" % shift.replace('_', '\\_'))
    plt.xlabel('Number of samples from test')
    plt.ylabel('$p$-value')
    plt.axhline(y=sign_level, color='k')
    plt.savefig("%s/%s_conf_noleg.pdf" % (path, DimensionalityReduction(dr).name), bbox_inches='tight')
    plt.legend()
    plt.savefig("%s/%s_conf.pdf" % (path, DimensionalityReduction(dr).name), bbox_inches='tight')
    plt.clf()

np.save("%s/samples_shifts_rands_dr_tech.npy" % (path), samples_shifts_rands_dr_tech)
